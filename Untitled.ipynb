# %%
import numpy as np
import seaborn
import math
from scipy import stats as stat
import pandas as pd
from matplotlib import pyplot as plt
seaborn.set(color_codes=True)

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#        i    v1    v2     e1     e2     i1     i2     d1     d2
# 0  19132  30.0  30.0  60.00  60.00   0.60   0.60   0.00   0.00
# 1  19142  30.0  30.0  60.00  60.00   1.20   1.20  -0.11  -0.33
# 2  19193  30.0  30.0  59.69  59.73   4.24   4.25  -6.04  -5.15
# 3  19248  30.0  30.0  59.22  59.32   7.50   7.51  -8.46  -7.44
# 4  19302  30.0  30.0  58.55  58.76  10.66  10.68 -12.40 -10.47

# %%
seaborn.scatterplot(x=data.i, y=data.v1)
seaborn.scatterplot(x=data.i, y=data.v2)

# %%
seaborn.scatterplot(x=data.i, y=data.i1)
seaborn.scatterplot(x=data.i, y=data.i2)

# %%
seaborn.scatterplot(x=data.i, y=data.d1)
seaborn.scatterplot(x=data.i, y=data.d2)

# %%
seaborn.scatterplot(x=data.i, y=data.e1)
seaborn.scatterplot(x=data.i, y=data.e2)
